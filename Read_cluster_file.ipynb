# %%
import h5py
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt

# %%
#fOR Reading hdf5 files

f = h5py.File('/home/ghoshsonia/rfi_RRI/testfile_32.hdf5', 'r')
f.keys()

# %%
d=np.load('Received_power_32.npy')

# %%
nside=32

# %%
#for plotting hdf5 files

test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(f["Received_power"][0,:,6])] = f["Received_power"][0,:,6]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 400 km for Received power in Kelvin at 90 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[0,:,6])] =d[0,:,6]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 400 km for Received power in Kelvin at 90 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()
# Out:
# 0.0 180.0 -180.0 180.0

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[1,:,6])] =d[1,:,6]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 3700 km for Received power in Kelvin at 90 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[0,:,26])] =d[0,:,26]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 400 km for Received power in Kelvin at 100 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()
# Out:
# 0.0 180.0 -180.0 180.0

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[1,:,26])] =d[1,:,26]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 3700 km for Received power in Kelvin at 100 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[0,:,14])] =d[0,:,14]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 400 km for Received power in Kelvin at 94 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[1,:,14])] =d[1,:,14]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 3700 km for Received power in Kelvin at 94 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[0,:,34])] =d[0,:,34]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 400 km for Received power in Kelvin at 104 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[1,:,34])] =d[1,:,34]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 3700 km for Received power in Kelvin at 104 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[0,:,41])] =d[0,:,41]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 400 km for Received power in Kelvin at 107.5 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[1,:,41])] =d[1,:,41]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 3700 km for Received power in Kelvin at 107.5 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[2,:,41])] =d[2,:,41]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 36000 km for Received power in Kelvin at 107.5 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()
# Out:
# 0.0 180.0 -180.0 180.0

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[2,:,34])] =d[2,:,34]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 36000 km for Received power in Kelvin at 104 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()

# %%
test_plot0001 = np.zeros(hp.nside2npix(nside))
test_plot0001[0:np.size(d[2,:,26])] =d[2,:,26]
hp.mollview(test_plot0001,cmap='inferno',unit="in Kelvin",title="Mollweide projection at an altitude 36000 km for Received power in Kelvin at 100 MHz",flip='geo',norm='hist')#,cb_orientation="vertical",title="Mollweide projection for Received power in Kelvin at 88.9MHz",flip='g')
hp.graticule()
# Out:
# 0.0 180.0 -180.0 180.0

# %%
freq=np.arange(87,108,0.5)

# %%
plt.bar(freq,d[0,1407,:]) 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('The brightness temperature of RFI [in Kelvin]')
plt.suptitle('Power spectrum over Germany at an altitude of 400 km',fontsize=14, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Power spectrum over Germany at an altitude of 400 km')

# %%
plt.bar(freq,d[2,1407,:]) 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('The brightness temperature of RFI [in Kelvin]')
plt.suptitle('Power spectrum over Germany at an altitude of 36000 km',fontsize=14, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Power spectrum over Germany at an altitude of 36000 km')

# %%
plt.bar(freq,d[0,8687,:]) 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('The brightness temperature of RFI [in Kelvin]')
plt.suptitle('Power spectrum over Australia at an altitude of 400 km',fontsize=14, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Power spectrum over Australia at an altitude of 400 km')

# %%
plt.bar(freq,d[2,8687,:]) 
plt.xlabel('Frequency [in MHz]')
plt.ylabel('The brightness temperature of RFI [in Kelvin]')
plt.suptitle('Power spectrum over Australia at an altitude of 36000 km',fontsize=14, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Power spectrum over Australia at an altitude of 36000 km')
